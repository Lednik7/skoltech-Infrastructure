# %%
from yolov_preproc.contours import create_contour, remove_mini_house
import os
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt

# %%
DATA_PATH = '/home/tema/CODE/skoltech-Infrastructure_2/data/digital_leaders'

path_to_image = os.path.join(DATA_PATH, 'images/train_image_002.png')

path_to_mask = os.path.join(DATA_PATH, 'masks/train_mask_002.png')

mask = np.array(Image.open(path_to_mask))

# %%
new_mask = remove_mini_house(mask, 1000)
# Out:
#   0%|          | 0/756 [00:00<?, ?it/s]
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# ...

# %%
plt.imshow(new_mask)

# %%
from src.modelling.metrics import DiceMetric

# %%
metric = DiceMetric()

# %%
import torch

# %%
metric(torch.Tensor(new_mask), torch.Tensor(mask))
# Out:
# tensor(0.9521)
